# %%
# Common Imports:
import pandas as pd
import numpy as np
import os

# To allow markdowns in Python Cells:
from IPython.display import display, Markdown
# display(Markdown("# Hello World!"))

# To Plot Pretty Figures:
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
# %matplotlib inline 

# allowing for any single variable to print out without using the print statement:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Path to access images
from pathlib import Path

# in-built keras image pre-processing library
from keras.preprocessing import image

# %%
# Path to folders with training data
parasitized_path = Path('cell_images/') / 'Parasitized'
not_parasitized_path = Path('cell_images/') / 'Uninfected'

# making sure the directories exist
parasitized_path.is_dir()
not_parasitized_path.is_dir()
# Out:
# True
# True

# %%
# initializing the lists of images (X) and labels (Y)
images = []
labels = []

# %%
# import library to resize images:
from skimage import transform

# setting the new shape of image:
new_shape = (224, 224, 3)

# %%
import warnings;
warnings.filterwarnings('ignore');

# Load all the non-malaria images and setting their Y label as 0
for img in not_parasitized_path.glob("*.png"):
    
    # Load the image from disk
    img = image.load_img(img)

    # Convert the image to a numpy array
    image_array = image.img_to_array(img)
    
    # resize the image (must be done after it has turned into a np array):
    image_array = transform.resize(image_array, new_shape, anti_aliasing=True)
    
    # scaling the image data to fall between 0-1 since images have 255 brightness values:
    image_array /= 255

    # Add the image to the list of images
    images.append(image_array)

    # For each 'not parasitized' image, the expected value should be 0
    labels.append(0)

# %%
# Load all the malaria images and setting their Y label as 1
for img in parasitized_path.glob("*.png"):
    
    # Load the image from disk
    img = image.load_img(img)

    # Convert the image to a numpy array
    image_array = image.img_to_array(img)
    
    # resize the image (must be done after it has turned into a np array):
    image_array = transform.resize(image_array, new_shape, anti_aliasing=True)
    
    # scaling the image data to fall between 0-1 since images have 255 brightness values:
    image_array /= 255

    # Add the image to the list of images
    images.append(image_array)

    # For each 'parasitized' image, the expected value should be 1
    labels.append(1)

# %%
from sklearn.utils import shuffle
images, labels = shuffle(images, labels)

# %%
# Create a single numpy array with all the images we loaded (list to np array)
x_data = np.array(images)

# Also convert the labels to a numpy array from a list
y_data = np.array(labels)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.2, random_state = 0)

# %%
# type convert the test and training data:
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
f'X_train shape: {X_train.shape}'
f'X_test.shape: {X_test.shape}'
# Out:
# 'X_train shape: (480, 224, 224, 3)'
# 'X_test.shape: (120, 224, 224, 3)'

# %%
# one hot encoding Y:
from keras.utils.np_utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
y_train.shape, y_test.shape
# Out:
# ((480, 2), (120, 2))

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.applications import vgg16
from tensorflow.keras.optimizers import Adam, SGD

# %%
vgg = tf.keras.applications.NASNetMobile(weights='imagenet', include_top=False, input_shape = (224,224,3))

    #for layer in vgg.layers[:-8]:  #Set block4 and block5 to be trainable. 
for layer in vgg.layers[:-5]:    #Set block5 trainable, all others as non-trainable
    print(layer.name)
    layer.trainable = False #All others as non-trainable.

x = vgg.output
x = GlobalAveragePooling2D()(x) #Use GlobalAveragePooling and NOT flatten. 
x = Dense(2, activation="softmax")(x)  #We are defining this as multiclass problem. 

model = Model(vgg.input, x)
model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy"])
# Out:
# input_1
# stem_conv1
# stem_bn1
# activation
# reduction_conv_1_stem_1
# reduction_bn_1_stem_1
# activation_1
# activation_3
# separable_conv_1_pad_reduction_left1_stem_1
# separable_conv_1_pad_reduction_right1_stem_1
# separable_conv_1_reduction_left1_stem_1
# separable_conv_1_reduction_right1_stem_1
# separable_conv_1_bn_reduction_left1_stem_1
# separable_conv_1_bn_reduction_right1_stem_1
# activation_2
# activation_4
# separable_conv_2_reduction_left1_stem_1
# separable_conv_2_reduction_right1_stem_1
# activation_5
# separable_conv_2_bn_reduction_left1_stem_1
# separable_conv_2_bn_reduction_right1_stem_1
# separable_conv_1_pad_reduction_right2_stem_1
# activation_7
# reduction_add_1_stem_1
# separable_conv_1_reduction_right2_stem_1
# separable_conv_1_pad_reduction_right3_stem_1
# activation_9
# separable_conv_1_bn_reduction_right2_stem_1
# separable_conv_1_reduction_right3_stem_1
# separable_conv_1_reduction_left4_stem_1
# activation_6
# separable_conv_1_bn_reduction_right3_stem_1
# separable_conv_1_bn_reduction_left4_stem_1
# reduction_pad_1_stem_1
# separable_conv_2_reduction_right2_stem_1
# activation_8
# activation_10
# reduction_left2_stem_1
# separable_conv_2_bn_reduction_right2_stem_1
# separable_conv_2_reduction_right3_stem_1
# separable_conv_2_reduction_left4_stem_1
# adjust_relu_1_stem_2
# reduction_add_2_stem_1
# reduction_left3_stem_1
# separable_conv_2_bn_reduction_right3_stem_1
# reduction_left4_stem_1
# separable_conv_2_bn_reduction_left4_stem_1
# reduction_right5_stem_1
# zero_padding2d
# reduction_add3_stem_1
# add
# reduction_add4_stem_1
# cropping2d
# reduction_concat_stem_1
# adjust_avg_pool_1_stem_2
# adjust_avg_pool_2_stem_2
# activation_11
# adjust_conv_1_stem_2
# adjust_conv_2_stem_2
# reduction_conv_1_stem_2
# concatenate
# reduction_bn_1_stem_2
# adjust_bn_stem_2
# activation_12
# activation_14
# separable_conv_1_pad_reduction_left1_stem_2
# separable_conv_1_pad_reduction_right1_stem_2
# separable_conv_1_reduction_left1_stem_2
# separable_conv_1_reduction_right1_stem_2
# separable_conv_1_bn_reduction_left1_stem_2
# separable_conv_1_bn_reduction_right1_stem_2
# activation_13
# activation_15
# separable_conv_2_reduction_left1_stem_2
# separable_conv_2_reduction_right1_stem_2
# activation_16
# separable_conv_2_bn_reduction_left1_stem_2
# separable_conv_2_bn_reduction_right1_stem_2
# separable_conv_1_pad_reduction_right2_stem_2
# activation_18
# reduction_add_1_stem_2
# separable_conv_1_reduction_right2_stem_2
# separable_conv_1_pad_reduction_right3_stem_2
# activation_20
# separable_conv_1_bn_reduction_right2_stem_2
# separable_conv_1_reduction_right3_stem_2
# separable_conv_1_reduction_left4_stem_2
# activation_17
# separable_conv_1_bn_reduction_right3_stem_2
# separable_conv_1_bn_reduction_left4_stem_2
# reduction_pad_1_stem_2
# separable_conv_2_reduction_right2_stem_2
# activation_19
# activation_21
# reduction_left2_stem_2
# separable_conv_2_bn_reduction_right2_stem_2
# separable_conv_2_reduction_right3_stem_2
# separable_conv_2_reduction_left4_stem_2
# adjust_relu_1_0
# reduction_add_2_stem_2
# reduction_left3_stem_2
# separable_conv_2_bn_reduction_right3_stem_2
# reduction_left4_stem_2
# separable_conv_2_bn_reduction_left4_stem_2
# reduction_right5_stem_2
# zero_padding2d_1
# reduction_add3_stem_2
# add_1
# reduction_add4_stem_2
# cropping2d_1
# reduction_concat_stem_2
# adjust_avg_pool_1_0
# adjust_avg_pool_2_0
# adjust_conv_1_0
# adjust_conv_2_0
# activation_22
# concatenate_1
# normal_conv_1_0
# adjust_bn_0
# normal_bn_1_0
# activation_23
# activation_25
# activation_27
# activation_29
# activation_31
# separable_conv_1_normal_left1_0
# separable_conv_1_normal_right1_0
# separable_conv_1_normal_left2_0
# separable_conv_1_normal_right2_0
# separable_conv_1_normal_left5_0
# separable_conv_1_bn_normal_left1_0
# separable_conv_1_bn_normal_right1_0
# separable_conv_1_bn_normal_left2_0
# separable_conv_1_bn_normal_right2_0
# separable_conv_1_bn_normal_left5_0
# activation_24
# activation_26
# activation_28
# activation_30
# activation_32
# separable_conv_2_normal_left1_0
# separable_conv_2_normal_right1_0
# separable_conv_2_normal_left2_0
# separable_conv_2_normal_right2_0
# separable_conv_2_normal_left5_0
# separable_conv_2_bn_normal_left1_0
# separable_conv_2_bn_normal_right1_0
# separable_conv_2_bn_normal_left2_0
# separable_conv_2_bn_normal_right2_0
# normal_left3_0
# normal_left4_0
# normal_right4_0
# separable_conv_2_bn_normal_left5_0
# normal_add_1_0
# normal_add_2_0
# normal_add_3_0
# normal_add_4_0
# normal_add_5_0
# normal_concat_0
# activation_33
# activation_34
# adjust_conv_projection_1
# normal_conv_1_1
# adjust_bn_1
# normal_bn_1_1
# activation_35
# activation_37
# activation_39
# activation_41
# activation_43
# separable_conv_1_normal_left1_1
# separable_conv_1_normal_right1_1
# separable_conv_1_normal_left2_1
# separable_conv_1_normal_right2_1
# separable_conv_1_normal_left5_1
# separable_conv_1_bn_normal_left1_1
# separable_conv_1_bn_normal_right1_1
# separable_conv_1_bn_normal_left2_1
# separable_conv_1_bn_normal_right2_1
# separable_conv_1_bn_normal_left5_1
# activation_36
# activation_38
# activation_40
# activation_42
# activation_44
# separable_conv_2_normal_left1_1
# separable_conv_2_normal_right1_1
# separable_conv_2_normal_left2_1
# separable_conv_2_normal_right2_1
# separable_conv_2_normal_left5_1
# separable_conv_2_bn_normal_left1_1
# separable_conv_2_bn_normal_right1_1
# separable_conv_2_bn_normal_left2_1
# separable_conv_2_bn_normal_right2_1
# normal_left3_1
# normal_left4_1
# normal_right4_1
# separable_conv_2_bn_normal_left5_1
# normal_add_1_1
# normal_add_2_1
# normal_add_3_1
# normal_add_4_1
# normal_add_5_1
# normal_concat_1
# activation_45
# activation_46
# adjust_conv_projection_2
# normal_conv_1_2
# adjust_bn_2
# normal_bn_1_2
# activation_47
# activation_49
# activation_51
# activation_53
# activation_55
# separable_conv_1_normal_left1_2
# separable_conv_1_normal_right1_2
# separable_conv_1_normal_left2_2
# separable_conv_1_normal_right2_2
# separable_conv_1_normal_left5_2
# separable_conv_1_bn_normal_left1_2
# separable_conv_1_bn_normal_right1_2
# separable_conv_1_bn_normal_left2_2
# separable_conv_1_bn_normal_right2_2
# separable_conv_1_bn_normal_left5_2
# activation_48
# activation_50
# activation_52
# activation_54
# activation_56
# separable_conv_2_normal_left1_2
# separable_conv_2_normal_right1_2
# separable_conv_2_normal_left2_2
# separable_conv_2_normal_right2_2
# separable_conv_2_normal_left5_2
# separable_conv_2_bn_normal_left1_2
# separable_conv_2_bn_normal_right1_2
# separable_conv_2_bn_normal_left2_2
# separable_conv_2_bn_normal_right2_2
# normal_left3_2
# normal_left4_2
# normal_right4_2
# separable_conv_2_bn_normal_left5_2
# normal_add_1_2
# normal_add_2_2
# normal_add_3_2
# normal_add_4_2
# normal_add_5_2
# normal_concat_2
# activation_57
# activation_58
# adjust_conv_projection_3
# normal_conv_1_3
# adjust_bn_3
# normal_bn_1_3
# activation_59
# activation_61
# activation_63
# activation_65
# activation_67
# separable_conv_1_normal_left1_3
# separable_conv_1_normal_right1_3
# separable_conv_1_normal_left2_3
# separable_conv_1_normal_right2_3
# separable_conv_1_normal_left5_3
# separable_conv_1_bn_normal_left1_3
# separable_conv_1_bn_normal_right1_3
# separable_conv_1_bn_normal_left2_3
# separable_conv_1_bn_normal_right2_3
# separable_conv_1_bn_normal_left5_3
# activation_60
# activation_62
# activation_64
# activation_66
# activation_68
# separable_conv_2_normal_left1_3
# separable_conv_2_normal_right1_3
# separable_conv_2_normal_left2_3
# separable_conv_2_normal_right2_3
# separable_conv_2_normal_left5_3
# separable_conv_2_bn_normal_left1_3
# separable_conv_2_bn_normal_right1_3
# separable_conv_2_bn_normal_left2_3
# separable_conv_2_bn_normal_right2_3
# normal_left3_3
# normal_left4_3
# normal_right4_3
# separable_conv_2_bn_normal_left5_3
# normal_add_1_3
# normal_add_2_3
# normal_add_3_3
# normal_add_4_3
# normal_add_5_3
# normal_concat_3
# activation_70
# activation_69
# reduction_conv_1_reduce_4
# adjust_conv_projection_reduce_4
# reduction_bn_1_reduce_4
# adjust_bn_reduce_4
# activation_71
# activation_73
# separable_conv_1_pad_reduction_left1_reduce_4
# separable_conv_1_pad_reduction_right1_reduce_4
# separable_conv_1_reduction_left1_reduce_4
# separable_conv_1_reduction_right1_reduce_4
# separable_conv_1_bn_reduction_left1_reduce_4
# separable_conv_1_bn_reduction_right1_reduce_4
# activation_72
# activation_74
# separable_conv_2_reduction_left1_reduce_4
# separable_conv_2_reduction_right1_reduce_4
# activation_75
# separable_conv_2_bn_reduction_left1_reduce_4
# separable_conv_2_bn_reduction_right1_reduce_4
# separable_conv_1_pad_reduction_right2_reduce_4
# activation_77
# reduction_add_1_reduce_4
# separable_conv_1_reduction_right2_reduce_4
# separable_conv_1_pad_reduction_right3_reduce_4
# activation_79
# separable_conv_1_bn_reduction_right2_reduce_4
# separable_conv_1_reduction_right3_reduce_4
# separable_conv_1_reduction_left4_reduce_4
# activation_76
# separable_conv_1_bn_reduction_right3_reduce_4
# separable_conv_1_bn_reduction_left4_reduce_4
# reduction_pad_1_reduce_4
# separable_conv_2_reduction_right2_reduce_4
# activation_78
# activation_80
# reduction_left2_reduce_4
# separable_conv_2_bn_reduction_right2_reduce_4
# separable_conv_2_reduction_right3_reduce_4
# separable_conv_2_reduction_left4_reduce_4
# adjust_relu_1_5
# reduction_add_2_reduce_4
# reduction_left3_reduce_4
# separable_conv_2_bn_reduction_right3_reduce_4
# reduction_left4_reduce_4
# separable_conv_2_bn_reduction_left4_reduce_4
# reduction_right5_reduce_4
# zero_padding2d_2
# reduction_add3_reduce_4
# add_2
# reduction_add4_reduce_4
# cropping2d_2
# reduction_concat_reduce_4
# adjust_avg_pool_1_5
# adjust_avg_pool_2_5
# adjust_conv_1_5
# adjust_conv_2_5
# activation_81
# concatenate_2
# normal_conv_1_5
# adjust_bn_5
# normal_bn_1_5
# activation_82
# activation_84
# activation_86
# activation_88
# activation_90
# separable_conv_1_normal_left1_5
# separable_conv_1_normal_right1_5
# separable_conv_1_normal_left2_5
# separable_conv_1_normal_right2_5
# separable_conv_1_normal_left5_5
# separable_conv_1_bn_normal_left1_5
# separable_conv_1_bn_normal_right1_5
# separable_conv_1_bn_normal_left2_5
# separable_conv_1_bn_normal_right2_5
# separable_conv_1_bn_normal_left5_5
# activation_83
# activation_85
# activation_87
# activation_89
# activation_91
# separable_conv_2_normal_left1_5
# separable_conv_2_normal_right1_5
# separable_conv_2_normal_left2_5
# separable_conv_2_normal_right2_5
# separable_conv_2_normal_left5_5
# separable_conv_2_bn_normal_left1_5
# separable_conv_2_bn_normal_right1_5
# separable_conv_2_bn_normal_left2_5
# separable_conv_2_bn_normal_right2_5
# normal_left3_5
# normal_left4_5
# normal_right4_5
# separable_conv_2_bn_normal_left5_5
# normal_add_1_5
# normal_add_2_5
# normal_add_3_5
# normal_add_4_5
# normal_add_5_5
# normal_concat_5
# activation_92
# activation_93
# adjust_conv_projection_6
# normal_conv_1_6
# adjust_bn_6
# normal_bn_1_6
# activation_94
# activation_96
# activation_98
# activation_100
# activation_102
# separable_conv_1_normal_left1_6
# separable_conv_1_normal_right1_6
# separable_conv_1_normal_left2_6
# separable_conv_1_normal_right2_6
# separable_conv_1_normal_left5_6
# separable_conv_1_bn_normal_left1_6
# separable_conv_1_bn_normal_right1_6
# separable_conv_1_bn_normal_left2_6
# separable_conv_1_bn_normal_right2_6
# separable_conv_1_bn_normal_left5_6
# activation_95
# activation_97
# activation_99
# activation_101
# activation_103
# separable_conv_2_normal_left1_6
# separable_conv_2_normal_right1_6
# separable_conv_2_normal_left2_6
# separable_conv_2_normal_right2_6
# separable_conv_2_normal_left5_6
# separable_conv_2_bn_normal_left1_6
# separable_conv_2_bn_normal_right1_6
# separable_conv_2_bn_normal_left2_6
# separable_conv_2_bn_normal_right2_6
# normal_left3_6
# normal_left4_6
# normal_right4_6
# separable_conv_2_bn_normal_left5_6
# normal_add_1_6
# normal_add_2_6
# normal_add_3_6
# normal_add_4_6
# normal_add_5_6
# normal_concat_6
# activation_104
# activation_105
# adjust_conv_projection_7
# normal_conv_1_7
# adjust_bn_7
# normal_bn_1_7
# activation_106
# activation_108
# activation_110
# activation_112
# activation_114
# separable_conv_1_normal_left1_7
# separable_conv_1_normal_right1_7
# separable_conv_1_normal_left2_7
# separable_conv_1_normal_right2_7
# separable_conv_1_normal_left5_7
# separable_conv_1_bn_normal_left1_7
# separable_conv_1_bn_normal_right1_7
# separable_conv_1_bn_normal_left2_7
# separable_conv_1_bn_normal_right2_7
# separable_conv_1_bn_normal_left5_7
# activation_107
# activation_109
# activation_111
# activation_113
# activation_115
# separable_conv_2_normal_left1_7
# separable_conv_2_normal_right1_7
# separable_conv_2_normal_left2_7
# separable_conv_2_normal_right2_7
# separable_conv_2_normal_left5_7
# separable_conv_2_bn_normal_left1_7
# separable_conv_2_bn_normal_right1_7
# separable_conv_2_bn_normal_left2_7
# separable_conv_2_bn_normal_right2_7
# normal_left3_7
# normal_left4_7
# normal_right4_7
# separable_conv_2_bn_normal_left5_7
# normal_add_1_7
# normal_add_2_7
# normal_add_3_7
# normal_add_4_7
# normal_add_5_7
# normal_concat_7
# activation_116
# activation_117
# adjust_conv_projection_8
# normal_conv_1_8
# adjust_bn_8
# normal_bn_1_8
# activation_118
# activation_120
# activation_122
# activation_124
# activation_126
# separable_conv_1_normal_left1_8
# separable_conv_1_normal_right1_8
# separable_conv_1_normal_left2_8
# separable_conv_1_normal_right2_8
# separable_conv_1_normal_left5_8
# separable_conv_1_bn_normal_left1_8
# separable_conv_1_bn_normal_right1_8
# separable_conv_1_bn_normal_left2_8
# separable_conv_1_bn_normal_right2_8
# separable_conv_1_bn_normal_left5_8
# activation_119
# activation_121
# activation_123
# activation_125
# activation_127
# separable_conv_2_normal_left1_8
# separable_conv_2_normal_right1_8
# separable_conv_2_normal_left2_8
# separable_conv_2_normal_right2_8
# separable_conv_2_normal_left5_8
# separable_conv_2_bn_normal_left1_8
# separable_conv_2_bn_normal_right1_8
# separable_conv_2_bn_normal_left2_8
# separable_conv_2_bn_normal_right2_8
# normal_left3_8
# normal_left4_8
# normal_right4_8
# separable_conv_2_bn_normal_left5_8
# normal_add_1_8
# normal_add_2_8
# normal_add_3_8
# normal_add_4_8
# normal_add_5_8
# normal_concat_8
# activation_129
# activation_128
# reduction_conv_1_reduce_8
# adjust_conv_projection_reduce_8
# reduction_bn_1_reduce_8
# adjust_bn_reduce_8
# activation_130
# activation_132
# separable_conv_1_pad_reduction_left1_reduce_8
# separable_conv_1_pad_reduction_right1_reduce_8
# separable_conv_1_reduction_left1_reduce_8
# separable_conv_1_reduction_right1_reduce_8
# separable_conv_1_bn_reduction_left1_reduce_8
# separable_conv_1_bn_reduction_right1_reduce_8
# activation_131
# activation_133
# separable_conv_2_reduction_left1_reduce_8
# separable_conv_2_reduction_right1_reduce_8
# activation_134
# separable_conv_2_bn_reduction_left1_reduce_8
# separable_conv_2_bn_reduction_right1_reduce_8
# separable_conv_1_pad_reduction_right2_reduce_8
# activation_136
# reduction_add_1_reduce_8
# separable_conv_1_reduction_right2_reduce_8
# separable_conv_1_pad_reduction_right3_reduce_8
# activation_138
# separable_conv_1_bn_reduction_right2_reduce_8
# separable_conv_1_reduction_right3_reduce_8
# separable_conv_1_reduction_left4_reduce_8
# activation_135
# separable_conv_1_bn_reduction_right3_reduce_8
# separable_conv_1_bn_reduction_left4_reduce_8
# reduction_pad_1_reduce_8
# separable_conv_2_reduction_right2_reduce_8
# activation_137
# activation_139
# reduction_left2_reduce_8
# separable_conv_2_bn_reduction_right2_reduce_8
# separable_conv_2_reduction_right3_reduce_8
# separable_conv_2_reduction_left4_reduce_8
# adjust_relu_1_9
# reduction_add_2_reduce_8
# reduction_left3_reduce_8
# separable_conv_2_bn_reduction_right3_reduce_8
# reduction_left4_reduce_8
# separable_conv_2_bn_reduction_left4_reduce_8
# reduction_right5_reduce_8
# zero_padding2d_3
# reduction_add3_reduce_8
# add_3
# reduction_add4_reduce_8
# cropping2d_3
# reduction_concat_reduce_8
# adjust_avg_pool_1_9
# adjust_avg_pool_2_9
# adjust_conv_1_9
# adjust_conv_2_9
# activation_140
# concatenate_3
# normal_conv_1_9
# adjust_bn_9
# normal_bn_1_9
# activation_141
# activation_143
# activation_145
# activation_147
# activation_149
# separable_conv_1_normal_left1_9
# separable_conv_1_normal_right1_9
# separable_conv_1_normal_left2_9
# separable_conv_1_normal_right2_9
# separable_conv_1_normal_left5_9
# separable_conv_1_bn_normal_left1_9
# separable_conv_1_bn_normal_right1_9
# separable_conv_1_bn_normal_left2_9
# separable_conv_1_bn_normal_right2_9
# separable_conv_1_bn_normal_left5_9
# activation_142
# activation_144
# activation_146
# activation_148
# activation_150
# separable_conv_2_normal_left1_9
# separable_conv_2_normal_right1_9
# separable_conv_2_normal_left2_9
# separable_conv_2_normal_right2_9
# separable_conv_2_normal_left5_9
# separable_conv_2_bn_normal_left1_9
# separable_conv_2_bn_normal_right1_9
# separable_conv_2_bn_normal_left2_9
# separable_conv_2_bn_normal_right2_9
# normal_left3_9
# normal_left4_9
# normal_right4_9
# separable_conv_2_bn_normal_left5_9
# normal_add_1_9
# normal_add_2_9
# normal_add_3_9
# normal_add_4_9
# normal_add_5_9
# normal_concat_9
# activation_151
# activation_152
# adjust_conv_projection_10
# normal_conv_1_10
# adjust_bn_10
# normal_bn_1_10
# activation_153
# activation_155
# activation_157
# activation_159
# activation_161
# separable_conv_1_normal_left1_10
# separable_conv_1_normal_right1_10
# separable_conv_1_normal_left2_10
# separable_conv_1_normal_right2_10
# separable_conv_1_normal_left5_10
# separable_conv_1_bn_normal_left1_10
# separable_conv_1_bn_normal_right1_10
# separable_conv_1_bn_normal_left2_10
# separable_conv_1_bn_normal_right2_10
# separable_conv_1_bn_normal_left5_10
# activation_154
# activation_156
# activation_158
# activation_160
# activation_162
# separable_conv_2_normal_left1_10
# separable_conv_2_normal_right1_10
# separable_conv_2_normal_left2_10
# separable_conv_2_normal_right2_10
# separable_conv_2_normal_left5_10
# separable_conv_2_bn_normal_left1_10
# separable_conv_2_bn_normal_right1_10
# separable_conv_2_bn_normal_left2_10
# separable_conv_2_bn_normal_right2_10
# normal_left3_10
# normal_left4_10
# normal_right4_10
# separable_conv_2_bn_normal_left5_10
# normal_add_1_10
# normal_add_2_10
# normal_add_3_10
# normal_add_4_10
# normal_add_5_10
# normal_concat_10
# activation_163
# activation_164
# adjust_conv_projection_11
# normal_conv_1_11
# adjust_bn_11
# normal_bn_1_11
# activation_165
# activation_167
# activation_169
# activation_171
# activation_173
# separable_conv_1_normal_left1_11
# separable_conv_1_normal_right1_11
# separable_conv_1_normal_left2_11
# separable_conv_1_normal_right2_11
# separable_conv_1_normal_left5_11
# separable_conv_1_bn_normal_left1_11
# separable_conv_1_bn_normal_right1_11
# separable_conv_1_bn_normal_left2_11
# separable_conv_1_bn_normal_right2_11
# separable_conv_1_bn_normal_left5_11
# activation_166
# activation_168
# activation_170
# activation_172
# activation_174
# separable_conv_2_normal_left1_11
# separable_conv_2_normal_right1_11
# separable_conv_2_normal_left2_11
# separable_conv_2_normal_right2_11
# separable_conv_2_normal_left5_11
# separable_conv_2_bn_normal_left1_11
# separable_conv_2_bn_normal_right1_11
# separable_conv_2_bn_normal_left2_11
# separable_conv_2_bn_normal_right2_11
# normal_left3_11
# normal_left4_11
# normal_right4_11
# separable_conv_2_bn_normal_left5_11
# normal_add_1_11
# normal_add_2_11
# normal_add_3_11
# normal_add_4_11
# normal_add_5_11
# normal_concat_11
# activation_175
# activation_176
# adjust_conv_projection_12
# normal_conv_1_12
# adjust_bn_12
# normal_bn_1_12
# activation_177
# activation_179
# activation_181
# activation_183
# activation_185
# separable_conv_1_normal_left1_12
# separable_conv_1_normal_right1_12
# separable_conv_1_normal_left2_12
# separable_conv_1_normal_right2_12
# separable_conv_1_normal_left5_12
# separable_conv_1_bn_normal_left1_12
# separable_conv_1_bn_normal_right1_12
# separable_conv_1_bn_normal_left2_12
# separable_conv_1_bn_normal_right2_12
# separable_conv_1_bn_normal_left5_12
# activation_178
# activation_180
# activation_182
# activation_184
# activation_186
# separable_conv_2_normal_left1_12
# separable_conv_2_normal_right1_12
# separable_conv_2_normal_left2_12
# separable_conv_2_normal_right2_12
# separable_conv_2_normal_left5_12
# separable_conv_2_bn_normal_left1_12
# separable_conv_2_bn_normal_right1_12
# separable_conv_2_bn_normal_left2_12
# separable_conv_2_bn_normal_right2_12
# normal_left3_12
# normal_left4_12
# normal_right4_12
# separable_conv_2_bn_normal_left5_12
# normal_add_1_12
# normal_add_2_12

# %%
# model.summary()

# %%
from keras.callbacks import ModelCheckpoint
filepath = "model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
hist = model.fit(X_train, y_train,
          batch_size=64,
          epochs=20,
          callbacks= callbacks_list,
          verbose=1,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 8/8 [==============================] - 19s 816ms/step - loss: 0.4453 - accuracy: 0.8500 - val_loss: 0.3973 - val_accuracy: 0.8500
#
# Epoch 00001: val_accuracy improved from -inf to 0.85000, saving model to model.h5
# Epoch 2/20
# 8/8 [==============================] - 2s 238ms/step - loss: 0.3028 - accuracy: 0.9250 - val_loss: 0.3060 - val_accuracy: 0.8833
#
# Epoch 00002: val_accuracy improved from 0.85000 to 0.88333, saving model to model.h5
# Epoch 3/20
# 8/8 [==============================] - 2s 237ms/step - loss: 0.2317 - accuracy: 0.9312 - val_loss: 0.2566 - val_accuracy: 0.9000
#
# Epoch 00003: val_accuracy improved from 0.88333 to 0.90000, saving model to model.h5
# Epoch 4/20
# 8/8 [==============================] - 2s 238ms/step - loss: 0.1910 - accuracy: 0.9479 - val_loss: 0.2183 - val_accuracy: 0.9250
#
# Epoch 00004: val_accuracy improved from 0.90000 to 0.92500, saving model to model.h5
# Epoch 5/20
# 8/8 [==============================] - 2s 238ms/step - loss: 0.1693 - accuracy: 0.9500 - val_loss: 0.1972 - val_accuracy: 0.9500
#
# Epoch 00005: val_accuracy improved from 0.92500 to 0.95000, saving model to model.h5
# Epoch 6/20
# 8/8 [==============================] - 2s 239ms/step - loss: 0.1475 - accuracy: 0.9521 - val_loss: 0.1810 - val_accuracy: 0.9500
#
# Epoch 00006: val_accuracy did not improve from 0.95000
# Epoch 7/20
# 8/8 [==============================] - 2s 239ms/step - loss: 0.1342 - accuracy: 0.9604 - val_loss: 0.1693 - val_accuracy: 0.9500
#
# Epoch 00007: val_accuracy did not improve from 0.95000
# Epoch 8/20
# 8/8 [==============================] - 2s 238ms/step - loss: 0.1243 - accuracy: 0.9646 - val_loss: 0.1593 - val_accuracy: 0.9500
#
# Epoch 00008: val_accuracy did not improve from 0.95000
# Epoch 9/20
# 8/8 [==============================] - 2s 241ms/step - loss: 0.1192 - accuracy: 0.9667 - val_loss: 0.1511 - val_accuracy: 0.9500
#
# Epoch 00009: val_accuracy did not improve from 0.95000
# Epoch 10/20
# 8/8 [==============================] - 2s 240ms/step - loss: 0.1102 - accuracy: 0.9667 - val_loss: 0.1443 - val_accuracy: 0.9500
#
# Epoch 00010: val_accuracy did not improve from 0.95000
# Epoch 11/20
# 8/8 [==============================] - 2s 241ms/step - loss: 0.1042 - accuracy: 0.9688 - val_loss: 0.1385 - val_accuracy: 0.9500
#
# Epoch 00011: val_accuracy did not improve from 0.95000
# Epoch 12/20
# 8/8 [==============================] - 2s 240ms/step - loss: 0.0993 - accuracy: 0.9729 - val_loss: 0.1342 - val_accuracy: 0.9500
#
# Epoch 00012: val_accuracy did not improve from 0.95000
# Epoch 13/20
# 8/8 [==============================] - 2s 240ms/step - loss: 0.0953 - accuracy: 0.9708 - val_loss: 0.1307 - val_accuracy: 0.9500
#
# Epoch 00013: val_accuracy did not improve from 0.95000
# Epoch 14/20
# 8/8 [==============================] - 2s 239ms/step - loss: 0.0914 - accuracy: 0.9750 - val_loss: 0.1287 - val_accuracy: 0.9500
#
# Epoch 00014: val_accuracy did not improve from 0.95000
# Epoch 15/20
# 8/8 [==============================] - 2s 242ms/step - loss: 0.0874 - accuracy: 0.9729 - val_loss: 0.1252 - val_accuracy: 0.9500
#
# Epoch 00015: val_accuracy did not improve from 0.95000
# Epoch 16/20
# 8/8 [==============================] - 2s 240ms/step - loss: 0.0859 - accuracy: 0.9750 - val_loss: 0.1240 - val_accuracy: 0.9500
#
# Epoch 00016: val_accuracy did not improve from 0.95000
# Epoch 17/20
# 8/8 [==============================] - 2s 239ms/step - loss: 0.0826 - accuracy: 0.9750 - val_loss: 0.1213 - val_accuracy: 0.9500
#
# Epoch 00017: val_accuracy did not improve from 0.95000
# Epoch 18/20
# 8/8 [==============================] - 2s 241ms/step - loss: 0.0795 - accuracy: 0.9750 - val_loss: 0.1198 - val_accuracy: 0.9500
#
# Epoch 00018: val_accuracy did not improve from 0.95000
# Epoch 19/20
# 8/8 [==============================] - 2s 241ms/step - loss: 0.0759 - accuracy: 0.9771 - val_loss: 0.1197 - val_accuracy: 0.9500
#
# Epoch 00019: val_accuracy did not improve from 0.95000
# Epoch 20/20
# 8/8 [==============================] - 2s 235ms/step - loss: 0.0737 - accuracy: 0.9812 - val_loss: 0.1172 - val_accuracy: 0.9500
#
# Epoch 00020: val_accuracy did not improve from 0.95000

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.11719243228435516
# Test accuracy: 0.949999988079071

# %%
epoch_list = list(range(1, len(hist.history['accuracy']) + 1))  # values for x axis [1, 2, ..., # of epochs]
plt.plot(epoch_list, hist.history['accuracy'], epoch_list, hist.history['val_accuracy'])
plt.legend(('Training Accuracy', 'Validation Accuracy'))
plt.show()

# %%
epoch_list = list(range(1, len(hist.history['loss']) + 1))  # values for x axis [1, 2, ..., # of epochs]
plt.plot(epoch_list, hist.history['loss'], epoch_list, hist.history['val_loss'])
plt.legend(('Training Accuracy', 'Validation Accuracy'))
plt.show()

# %%
pd.DataFrame(hist.history).plot(figsize=(8,5))
plt.ylabel('loss, accuracy')
plt.xlabel('epoch')
plt.legend(['train_loss','train_acc', 'val_loss','val_acc'],fontsize=18)
plt.show()
# Out:
# <AxesSubplot:>
# Text(0, 0.5, 'loss, accuracy')
# Text(0.5, 0, 'epoch')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = np.argmax(model.predict(X_test), axis=1)
cm=confusion_matrix(np.argmax(y_test, axis=1), y_pred)  
sns.heatmap(cm, annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = np.argmax(model.predict(X_test), axis=1)
cm=confusion_matrix(np.argmax(y_test, axis=1), y_pred)  
sns.heatmap(cm, annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %%
import scipy

parasited_image_idx = np.where(y_pred == 1)[0]

#Save all images classified as parasited to a directory (optional, makes sense for large data sets)
#capture it in memory as an array
predicted_as_para=[]
for i in parasited_image_idx:
    par_img = X_test[i]
    #plt.imsave("results_classified_as_para/para_"+str(i)+".png", par_img)
    predicted_as_para.append(par_img)
    
predicted_as_para = np.array(predicted_as_para)    

print(img.shape[0],img.shape[1])

from matplotlib.patches import Rectangle #To add a rectangle overlay to the image
from skimage.feature.peak import peak_local_max  #To detect hotspots in 2D images. 
def plot_heatmap(img):
  
    pred = model.predict(np.expand_dims(img, axis=0))
    pred_class = np.argmax(pred)
    print(pred_class)
    #Get weights for all classes from the prediction layer
    last_layer_weights = model.layers[-1].get_weights()[0] #Prediction layer
    print(last_layer_weights.shape)
    #Get weights for the predicted class.
    last_layer_weights_for_pred = last_layer_weights[:, pred_class]
    print(last_layer_weights_for_pred)
    print(last_layer_weights_for_pred.shape)
    #Get output from the last conv. layer
    last_conv_model = Model(model.input, model.get_layer("normal_concat_12").output)
    last_conv_output = last_conv_model.predict(img[np.newaxis,:,:,:])
    last_conv_output = np.squeeze(last_conv_output)
    print(last_conv_output.shape)
    
    #Upsample/resize the last conv. output to same size as original image
    h = int(img.shape[0]/last_conv_output.shape[0])
    w = int(img.shape[1]/last_conv_output.shape[1])
    upsampled_last_conv_output = scipy.ndimage.zoom(last_conv_output, (h, w, 1), order=1)
    
    heat_map = np.dot(upsampled_last_conv_output.reshape((img.shape[0]*img.shape[1], 1056)), 
                 last_layer_weights_for_pred).reshape(img.shape[0],img.shape[1])
    
    #Since we have a lot of dark pixels where the edges may be thought of as 
    #high anomaly, let us drop all heat map values in this region to 0.
    #This is an optional step based on the image. 
    heat_map[img[:,:,0] == 0] = 0  #All dark pixels outside the object set to 0
    
    #Detect peaks (hot spots) in the heat map. We will set it to detect maximum 5 peaks.
    #with rel threshold of 0.5 (compared to the max peak). 
    peak_coords = peak_local_max(heat_map, num_peaks=5, threshold_rel=0.5, min_distance=10) 

    plt.imshow(img.astype('float32').reshape(img.shape[0],img.shape[1],3))
    plt.imshow(heat_map, cmap='jet', alpha=0.30)
    for i in range(0,peak_coords.shape[0]):
        print(i)
        y = peak_coords[i,0]
        x = peak_coords[i,1]
        plt.gca().add_patch(Rectangle((x-25, y-25), 50,50,linewidth=1,edgecolor='r',facecolor='none'))

    

import random 
im = random.randint(0,predicted_as_para.shape[0]-1)
heat_map =plot_heatmap(predicted_as_para[im])

img = predicted_as_para[im]
plt.imshow(predicted_as_para[im])
# Out:
# 224 224
# 1
# (1056, 2)
# [ 0.03415687  0.06857686 -0.04940943 ... -0.00978123  0.03361819
#  -0.06319392]
# (1056,)
# (7, 7, 1056)
# 0
# 1
# 2
# 3
# 4

# %%
vgg = tf.keras.applications.NASNetMobile(weights='imagenet', include_top=False, input_shape = (224,224,3))

    #for layer in vgg.layers[:-8]:  #Set block4 and block5 to be trainable. 
#     layer.trainable = False #All others as non-trainable.

x = vgg.output
x = GlobalAveragePooling2D()(x) #Use GlobalAveragePooling and NOT flatten. 
x = Dense(2, activation="softmax")(x)  #We are defining this as multiclass problem. 

model = Model(vgg.input, x)
# model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy"])
for layer in model.layers:    #Set block5 trainable, all others as non-trainable
    print(layer.name)
# Out:
# input_2
# stem_conv1
# stem_bn1
# activation_188
# reduction_conv_1_stem_1
# reduction_bn_1_stem_1
# activation_189
# activation_191
# separable_conv_1_pad_reduction_left1_stem_1
# separable_conv_1_pad_reduction_right1_stem_1
# separable_conv_1_reduction_left1_stem_1
# separable_conv_1_reduction_right1_stem_1
# separable_conv_1_bn_reduction_left1_stem_1
# separable_conv_1_bn_reduction_right1_stem_1
# activation_190
# activation_192
# separable_conv_2_reduction_left1_stem_1
# separable_conv_2_reduction_right1_stem_1
# activation_193
# separable_conv_2_bn_reduction_left1_stem_1
# separable_conv_2_bn_reduction_right1_stem_1
# separable_conv_1_pad_reduction_right2_stem_1
# activation_195
# reduction_add_1_stem_1
# separable_conv_1_reduction_right2_stem_1
# separable_conv_1_pad_reduction_right3_stem_1
# activation_197
# separable_conv_1_bn_reduction_right2_stem_1
# separable_conv_1_reduction_right3_stem_1
# separable_conv_1_reduction_left4_stem_1
# activation_194
# separable_conv_1_bn_reduction_right3_stem_1
# separable_conv_1_bn_reduction_left4_stem_1
# reduction_pad_1_stem_1
# separable_conv_2_reduction_right2_stem_1
# activation_196
# activation_198
# reduction_left2_stem_1
# separable_conv_2_bn_reduction_right2_stem_1
# separable_conv_2_reduction_right3_stem_1
# separable_conv_2_reduction_left4_stem_1
# adjust_relu_1_stem_2
# reduction_add_2_stem_1
# reduction_left3_stem_1
# separable_conv_2_bn_reduction_right3_stem_1
# reduction_left4_stem_1
# separable_conv_2_bn_reduction_left4_stem_1
# reduction_right5_stem_1
# zero_padding2d_4
# reduction_add3_stem_1
# add_4
# reduction_add4_stem_1
# cropping2d_4
# reduction_concat_stem_1
# adjust_avg_pool_1_stem_2
# adjust_avg_pool_2_stem_2
# activation_199
# adjust_conv_1_stem_2
# adjust_conv_2_stem_2
# reduction_conv_1_stem_2
# concatenate_4
# reduction_bn_1_stem_2
# adjust_bn_stem_2
# activation_200
# activation_202
# separable_conv_1_pad_reduction_left1_stem_2
# separable_conv_1_pad_reduction_right1_stem_2
# separable_conv_1_reduction_left1_stem_2
# separable_conv_1_reduction_right1_stem_2
# separable_conv_1_bn_reduction_left1_stem_2
# separable_conv_1_bn_reduction_right1_stem_2
# activation_201
# activation_203
# separable_conv_2_reduction_left1_stem_2
# separable_conv_2_reduction_right1_stem_2
# activation_204
# separable_conv_2_bn_reduction_left1_stem_2
# separable_conv_2_bn_reduction_right1_stem_2
# separable_conv_1_pad_reduction_right2_stem_2
# activation_206
# reduction_add_1_stem_2
# separable_conv_1_reduction_right2_stem_2
# separable_conv_1_pad_reduction_right3_stem_2
# activation_208
# separable_conv_1_bn_reduction_right2_stem_2
# separable_conv_1_reduction_right3_stem_2
# separable_conv_1_reduction_left4_stem_2
# activation_205
# separable_conv_1_bn_reduction_right3_stem_2
# separable_conv_1_bn_reduction_left4_stem_2
# reduction_pad_1_stem_2
# separable_conv_2_reduction_right2_stem_2
# activation_207
# activation_209
# reduction_left2_stem_2
# separable_conv_2_bn_reduction_right2_stem_2
# separable_conv_2_reduction_right3_stem_2
# separable_conv_2_reduction_left4_stem_2
# adjust_relu_1_0
# reduction_add_2_stem_2
# reduction_left3_stem_2
# separable_conv_2_bn_reduction_right3_stem_2
# reduction_left4_stem_2
# separable_conv_2_bn_reduction_left4_stem_2
# reduction_right5_stem_2
# zero_padding2d_5
# reduction_add3_stem_2
# add_5
# reduction_add4_stem_2
# cropping2d_5
# reduction_concat_stem_2
# adjust_avg_pool_1_0
# adjust_avg_pool_2_0
# adjust_conv_1_0
# adjust_conv_2_0
# activation_210
# concatenate_5
# normal_conv_1_0
# adjust_bn_0
# normal_bn_1_0
# activation_211
# activation_213
# activation_215
# activation_217
# activation_219
# separable_conv_1_normal_left1_0
# separable_conv_1_normal_right1_0
# separable_conv_1_normal_left2_0
# separable_conv_1_normal_right2_0
# separable_conv_1_normal_left5_0
# separable_conv_1_bn_normal_left1_0
# separable_conv_1_bn_normal_right1_0
# separable_conv_1_bn_normal_left2_0
# separable_conv_1_bn_normal_right2_0
# separable_conv_1_bn_normal_left5_0
# activation_212
# activation_214
# activation_216
# activation_218
# activation_220
# separable_conv_2_normal_left1_0
# separable_conv_2_normal_right1_0
# separable_conv_2_normal_left2_0
# separable_conv_2_normal_right2_0
# separable_conv_2_normal_left5_0
# separable_conv_2_bn_normal_left1_0
# separable_conv_2_bn_normal_right1_0
# separable_conv_2_bn_normal_left2_0
# separable_conv_2_bn_normal_right2_0
# normal_left3_0
# normal_left4_0
# normal_right4_0
# separable_conv_2_bn_normal_left5_0
# normal_add_1_0
# normal_add_2_0
# normal_add_3_0
# normal_add_4_0
# normal_add_5_0
# normal_concat_0
# activation_221
# activation_222
# adjust_conv_projection_1
# normal_conv_1_1
# adjust_bn_1
# normal_bn_1_1
# activation_223
# activation_225
# activation_227
# activation_229
# activation_231
# separable_conv_1_normal_left1_1
# separable_conv_1_normal_right1_1
# separable_conv_1_normal_left2_1
# separable_conv_1_normal_right2_1
# separable_conv_1_normal_left5_1
# separable_conv_1_bn_normal_left1_1
# separable_conv_1_bn_normal_right1_1
# separable_conv_1_bn_normal_left2_1
# separable_conv_1_bn_normal_right2_1
# separable_conv_1_bn_normal_left5_1
# activation_224
# activation_226
# activation_228
# activation_230
# activation_232
# separable_conv_2_normal_left1_1
# separable_conv_2_normal_right1_1
# separable_conv_2_normal_left2_1
# separable_conv_2_normal_right2_1
# separable_conv_2_normal_left5_1
# separable_conv_2_bn_normal_left1_1
# separable_conv_2_bn_normal_right1_1
# separable_conv_2_bn_normal_left2_1
# separable_conv_2_bn_normal_right2_1
# normal_left3_1
# normal_left4_1
# normal_right4_1
# separable_conv_2_bn_normal_left5_1
# normal_add_1_1
# normal_add_2_1
# normal_add_3_1
# normal_add_4_1
# normal_add_5_1
# normal_concat_1
# activation_233
# activation_234
# adjust_conv_projection_2
# normal_conv_1_2
# adjust_bn_2
# normal_bn_1_2
# activation_235
# activation_237
# activation_239
# activation_241
# activation_243
# separable_conv_1_normal_left1_2
# separable_conv_1_normal_right1_2
# separable_conv_1_normal_left2_2
# separable_conv_1_normal_right2_2
# separable_conv_1_normal_left5_2
# separable_conv_1_bn_normal_left1_2
# separable_conv_1_bn_normal_right1_2
# separable_conv_1_bn_normal_left2_2
# separable_conv_1_bn_normal_right2_2
# separable_conv_1_bn_normal_left5_2
# activation_236
# activation_238
# activation_240
# activation_242
# activation_244
# separable_conv_2_normal_left1_2
# separable_conv_2_normal_right1_2
# separable_conv_2_normal_left2_2
# separable_conv_2_normal_right2_2
# separable_conv_2_normal_left5_2
# separable_conv_2_bn_normal_left1_2
# separable_conv_2_bn_normal_right1_2
# separable_conv_2_bn_normal_left2_2
# separable_conv_2_bn_normal_right2_2
# normal_left3_2
# normal_left4_2
# normal_right4_2
# separable_conv_2_bn_normal_left5_2
# normal_add_1_2
# normal_add_2_2
# normal_add_3_2
# normal_add_4_2
# normal_add_5_2
# normal_concat_2
# activation_245
# activation_246
# adjust_conv_projection_3
# normal_conv_1_3
# adjust_bn_3
# normal_bn_1_3
# activation_247
# activation_249
# activation_251
# activation_253
# activation_255
# separable_conv_1_normal_left1_3
# separable_conv_1_normal_right1_3
# separable_conv_1_normal_left2_3
# separable_conv_1_normal_right2_3
# separable_conv_1_normal_left5_3
# separable_conv_1_bn_normal_left1_3
# separable_conv_1_bn_normal_right1_3
# separable_conv_1_bn_normal_left2_3
# separable_conv_1_bn_normal_right2_3
# separable_conv_1_bn_normal_left5_3
# activation_248
# activation_250
# activation_252
# activation_254
# activation_256
# separable_conv_2_normal_left1_3
# separable_conv_2_normal_right1_3
# separable_conv_2_normal_left2_3
# separable_conv_2_normal_right2_3
# separable_conv_2_normal_left5_3
# separable_conv_2_bn_normal_left1_3
# separable_conv_2_bn_normal_right1_3
# separable_conv_2_bn_normal_left2_3
# separable_conv_2_bn_normal_right2_3
# normal_left3_3
# normal_left4_3
# normal_right4_3
# separable_conv_2_bn_normal_left5_3
# normal_add_1_3
# normal_add_2_3
# normal_add_3_3
# normal_add_4_3
# normal_add_5_3
# normal_concat_3
# activation_258
# activation_257
# reduction_conv_1_reduce_4
# adjust_conv_projection_reduce_4
# reduction_bn_1_reduce_4
# adjust_bn_reduce_4
# activation_259
# activation_261
# separable_conv_1_pad_reduction_left1_reduce_4
# separable_conv_1_pad_reduction_right1_reduce_4
# separable_conv_1_reduction_left1_reduce_4
# separable_conv_1_reduction_right1_reduce_4
# separable_conv_1_bn_reduction_left1_reduce_4
# separable_conv_1_bn_reduction_right1_reduce_4
# activation_260
# activation_262
# separable_conv_2_reduction_left1_reduce_4
# separable_conv_2_reduction_right1_reduce_4
# activation_263
# separable_conv_2_bn_reduction_left1_reduce_4
# separable_conv_2_bn_reduction_right1_reduce_4
# separable_conv_1_pad_reduction_right2_reduce_4
# activation_265
# reduction_add_1_reduce_4
# separable_conv_1_reduction_right2_reduce_4
# separable_conv_1_pad_reduction_right3_reduce_4
# activation_267
# separable_conv_1_bn_reduction_right2_reduce_4
# separable_conv_1_reduction_right3_reduce_4
# separable_conv_1_reduction_left4_reduce_4
# activation_264
# separable_conv_1_bn_reduction_right3_reduce_4
# separable_conv_1_bn_reduction_left4_reduce_4
# reduction_pad_1_reduce_4
# separable_conv_2_reduction_right2_reduce_4
# activation_266
# activation_268
# reduction_left2_reduce_4
# separable_conv_2_bn_reduction_right2_reduce_4
# separable_conv_2_reduction_right3_reduce_4
# separable_conv_2_reduction_left4_reduce_4
# adjust_relu_1_5
# reduction_add_2_reduce_4
# reduction_left3_reduce_4
# separable_conv_2_bn_reduction_right3_reduce_4
# reduction_left4_reduce_4
# separable_conv_2_bn_reduction_left4_reduce_4
# reduction_right5_reduce_4
# zero_padding2d_6
# reduction_add3_reduce_4
# add_6
# reduction_add4_reduce_4
# cropping2d_6
# reduction_concat_reduce_4
# adjust_avg_pool_1_5
# adjust_avg_pool_2_5
# adjust_conv_1_5
# adjust_conv_2_5
# activation_269
# concatenate_6
# normal_conv_1_5
# adjust_bn_5
# normal_bn_1_5
# activation_270
# activation_272
# activation_274
# activation_276
# activation_278
# separable_conv_1_normal_left1_5
# separable_conv_1_normal_right1_5
# separable_conv_1_normal_left2_5
# separable_conv_1_normal_right2_5
# separable_conv_1_normal_left5_5
# separable_conv_1_bn_normal_left1_5
# separable_conv_1_bn_normal_right1_5
# separable_conv_1_bn_normal_left2_5
# separable_conv_1_bn_normal_right2_5
# separable_conv_1_bn_normal_left5_5
# activation_271
# activation_273
# activation_275
# activation_277
# activation_279
# separable_conv_2_normal_left1_5
# separable_conv_2_normal_right1_5
# separable_conv_2_normal_left2_5
# separable_conv_2_normal_right2_5
# separable_conv_2_normal_left5_5
# separable_conv_2_bn_normal_left1_5
# separable_conv_2_bn_normal_right1_5
# separable_conv_2_bn_normal_left2_5
# separable_conv_2_bn_normal_right2_5
# normal_left3_5
# normal_left4_5
# normal_right4_5
# separable_conv_2_bn_normal_left5_5
# normal_add_1_5
# normal_add_2_5
# normal_add_3_5
# normal_add_4_5
# normal_add_5_5
# normal_concat_5
# activation_280
# activation_281
# adjust_conv_projection_6
# normal_conv_1_6
# adjust_bn_6
# normal_bn_1_6
# activation_282
# activation_284
# activation_286
# activation_288
# activation_290
# separable_conv_1_normal_left1_6
# separable_conv_1_normal_right1_6
# separable_conv_1_normal_left2_6
# separable_conv_1_normal_right2_6
# separable_conv_1_normal_left5_6
# separable_conv_1_bn_normal_left1_6
# separable_conv_1_bn_normal_right1_6
# separable_conv_1_bn_normal_left2_6
# separable_conv_1_bn_normal_right2_6
# separable_conv_1_bn_normal_left5_6
# activation_283
# activation_285
# activation_287
# activation_289
# activation_291
# separable_conv_2_normal_left1_6
# separable_conv_2_normal_right1_6
# separable_conv_2_normal_left2_6
# separable_conv_2_normal_right2_6
# separable_conv_2_normal_left5_6
# separable_conv_2_bn_normal_left1_6
# separable_conv_2_bn_normal_right1_6
# separable_conv_2_bn_normal_left2_6
# separable_conv_2_bn_normal_right2_6
# normal_left3_6
# normal_left4_6
# normal_right4_6
# separable_conv_2_bn_normal_left5_6
# normal_add_1_6
# normal_add_2_6
# normal_add_3_6
# normal_add_4_6
# normal_add_5_6
# normal_concat_6
# activation_292
# activation_293
# adjust_conv_projection_7
# normal_conv_1_7
# adjust_bn_7
# normal_bn_1_7
# activation_294
# activation_296
# activation_298
# activation_300
# activation_302
# separable_conv_1_normal_left1_7
# separable_conv_1_normal_right1_7
# separable_conv_1_normal_left2_7
# separable_conv_1_normal_right2_7
# separable_conv_1_normal_left5_7
# separable_conv_1_bn_normal_left1_7
# separable_conv_1_bn_normal_right1_7
# separable_conv_1_bn_normal_left2_7
# separable_conv_1_bn_normal_right2_7
# separable_conv_1_bn_normal_left5_7
# activation_295
# activation_297
# activation_299
# activation_301
# activation_303
# separable_conv_2_normal_left1_7
# separable_conv_2_normal_right1_7
# separable_conv_2_normal_left2_7
# separable_conv_2_normal_right2_7
# separable_conv_2_normal_left5_7
# separable_conv_2_bn_normal_left1_7
# separable_conv_2_bn_normal_right1_7
# separable_conv_2_bn_normal_left2_7
# separable_conv_2_bn_normal_right2_7
# normal_left3_7
# normal_left4_7
# normal_right4_7
# separable_conv_2_bn_normal_left5_7
# normal_add_1_7
# normal_add_2_7
# normal_add_3_7
# normal_add_4_7
# normal_add_5_7
# normal_concat_7
# activation_304
# activation_305
# adjust_conv_projection_8
# normal_conv_1_8
# adjust_bn_8
# normal_bn_1_8
# activation_306
# activation_308
# activation_310
# activation_312
# activation_314
# separable_conv_1_normal_left1_8
# separable_conv_1_normal_right1_8
# separable_conv_1_normal_left2_8
# separable_conv_1_normal_right2_8
# separable_conv_1_normal_left5_8
# separable_conv_1_bn_normal_left1_8
# separable_conv_1_bn_normal_right1_8
# separable_conv_1_bn_normal_left2_8
# separable_conv_1_bn_normal_right2_8
# separable_conv_1_bn_normal_left5_8
# activation_307
# activation_309
# activation_311
# activation_313
# activation_315
# separable_conv_2_normal_left1_8
# separable_conv_2_normal_right1_8
# separable_conv_2_normal_left2_8
# separable_conv_2_normal_right2_8
# separable_conv_2_normal_left5_8
# separable_conv_2_bn_normal_left1_8
# separable_conv_2_bn_normal_right1_8
# separable_conv_2_bn_normal_left2_8
# separable_conv_2_bn_normal_right2_8
# normal_left3_8
# normal_left4_8
# normal_right4_8
# separable_conv_2_bn_normal_left5_8
# normal_add_1_8
# normal_add_2_8
# normal_add_3_8
# normal_add_4_8
# normal_add_5_8
# normal_concat_8
# activation_317
# activation_316
# reduction_conv_1_reduce_8
# adjust_conv_projection_reduce_8
# reduction_bn_1_reduce_8
# adjust_bn_reduce_8
# activation_318
# activation_320
# separable_conv_1_pad_reduction_left1_reduce_8
# separable_conv_1_pad_reduction_right1_reduce_8
# separable_conv_1_reduction_left1_reduce_8
# separable_conv_1_reduction_right1_reduce_8
# separable_conv_1_bn_reduction_left1_reduce_8
# separable_conv_1_bn_reduction_right1_reduce_8
# activation_319
# activation_321
# separable_conv_2_reduction_left1_reduce_8
# separable_conv_2_reduction_right1_reduce_8
# activation_322
# separable_conv_2_bn_reduction_left1_reduce_8
# separable_conv_2_bn_reduction_right1_reduce_8
# separable_conv_1_pad_reduction_right2_reduce_8
# activation_324
# reduction_add_1_reduce_8
# separable_conv_1_reduction_right2_reduce_8
# separable_conv_1_pad_reduction_right3_reduce_8
# activation_326
# separable_conv_1_bn_reduction_right2_reduce_8
# separable_conv_1_reduction_right3_reduce_8
# separable_conv_1_reduction_left4_reduce_8
# activation_323
# separable_conv_1_bn_reduction_right3_reduce_8
# separable_conv_1_bn_reduction_left4_reduce_8
# reduction_pad_1_reduce_8
# separable_conv_2_reduction_right2_reduce_8
# activation_325
# activation_327
# reduction_left2_reduce_8
# separable_conv_2_bn_reduction_right2_reduce_8
# separable_conv_2_reduction_right3_reduce_8
# separable_conv_2_reduction_left4_reduce_8
# adjust_relu_1_9
# reduction_add_2_reduce_8
# reduction_left3_reduce_8
# separable_conv_2_bn_reduction_right3_reduce_8
# reduction_left4_reduce_8
# separable_conv_2_bn_reduction_left4_reduce_8
# reduction_right5_reduce_8
# zero_padding2d_7
# reduction_add3_reduce_8
# add_7
# reduction_add4_reduce_8
# cropping2d_7
# reduction_concat_reduce_8
# adjust_avg_pool_1_9
# adjust_avg_pool_2_9
# adjust_conv_1_9
# adjust_conv_2_9
# activation_328
# concatenate_7
# normal_conv_1_9
# adjust_bn_9
# normal_bn_1_9
# activation_329
# activation_331
# activation_333
# activation_335
# activation_337
# separable_conv_1_normal_left1_9
# separable_conv_1_normal_right1_9
# separable_conv_1_normal_left2_9
# separable_conv_1_normal_right2_9
# separable_conv_1_normal_left5_9
# separable_conv_1_bn_normal_left1_9
# separable_conv_1_bn_normal_right1_9
# separable_conv_1_bn_normal_left2_9
# separable_conv_1_bn_normal_right2_9
# separable_conv_1_bn_normal_left5_9
# activation_330
# activation_332
# activation_334
# activation_336
# activation_338
# separable_conv_2_normal_left1_9
# separable_conv_2_normal_right1_9
# separable_conv_2_normal_left2_9
# separable_conv_2_normal_right2_9
# separable_conv_2_normal_left5_9
# separable_conv_2_bn_normal_left1_9
# separable_conv_2_bn_normal_right1_9
# separable_conv_2_bn_normal_left2_9
# separable_conv_2_bn_normal_right2_9
# normal_left3_9
# normal_left4_9
# normal_right4_9
# separable_conv_2_bn_normal_left5_9
# normal_add_1_9
# normal_add_2_9
# normal_add_3_9
# normal_add_4_9
# normal_add_5_9
# normal_concat_9
# activation_339
# activation_340
# adjust_conv_projection_10
# normal_conv_1_10
# adjust_bn_10
# normal_bn_1_10
# activation_341
# activation_343
# activation_345
# activation_347
# activation_349
# separable_conv_1_normal_left1_10
# separable_conv_1_normal_right1_10
# separable_conv_1_normal_left2_10
# separable_conv_1_normal_right2_10
# separable_conv_1_normal_left5_10
# separable_conv_1_bn_normal_left1_10
# separable_conv_1_bn_normal_right1_10
# separable_conv_1_bn_normal_left2_10
# separable_conv_1_bn_normal_right2_10
# separable_conv_1_bn_normal_left5_10
# activation_342
# activation_344
# activation_346
# activation_348
# activation_350
# separable_conv_2_normal_left1_10
# separable_conv_2_normal_right1_10
# separable_conv_2_normal_left2_10
# separable_conv_2_normal_right2_10
# separable_conv_2_normal_left5_10
# separable_conv_2_bn_normal_left1_10
# separable_conv_2_bn_normal_right1_10
# separable_conv_2_bn_normal_left2_10
# separable_conv_2_bn_normal_right2_10
# normal_left3_10
# normal_left4_10
# normal_right4_10
# separable_conv_2_bn_normal_left5_10
# normal_add_1_10
# normal_add_2_10
# normal_add_3_10
# normal_add_4_10
# normal_add_5_10
# normal_concat_10
# activation_351
# activation_352
# adjust_conv_projection_11
# normal_conv_1_11
# adjust_bn_11
# normal_bn_1_11
# activation_353
# activation_355
# activation_357
# activation_359
# activation_361
# separable_conv_1_normal_left1_11
# separable_conv_1_normal_right1_11
# separable_conv_1_normal_left2_11
# separable_conv_1_normal_right2_11
# separable_conv_1_normal_left5_11
# separable_conv_1_bn_normal_left1_11
# separable_conv_1_bn_normal_right1_11
# separable_conv_1_bn_normal_left2_11
# separable_conv_1_bn_normal_right2_11
# separable_conv_1_bn_normal_left5_11
# activation_354
# activation_356
# activation_358
# activation_360
# activation_362
# separable_conv_2_normal_left1_11
# separable_conv_2_normal_right1_11
# separable_conv_2_normal_left2_11
# separable_conv_2_normal_right2_11
# separable_conv_2_normal_left5_11
# separable_conv_2_bn_normal_left1_11
# separable_conv_2_bn_normal_right1_11
# separable_conv_2_bn_normal_left2_11
# separable_conv_2_bn_normal_right2_11
# normal_left3_11
# normal_left4_11
# normal_right4_11
# separable_conv_2_bn_normal_left5_11
# normal_add_1_11
# normal_add_2_11
# normal_add_3_11
# normal_add_4_11
# normal_add_5_11
# normal_concat_11
# activation_363
# activation_364
# adjust_conv_projection_12
# normal_conv_1_12
# adjust_bn_12
# normal_bn_1_12
# activation_365
# activation_367
# activation_369
# activation_371
# activation_373
# separable_conv_1_normal_left1_12
# separable_conv_1_normal_right1_12
# separable_conv_1_normal_left2_12
# separable_conv_1_normal_right2_12
# separable_conv_1_normal_left5_12
# separable_conv_1_bn_normal_left1_12
# separable_conv_1_bn_normal_right1_12
# separable_conv_1_bn_normal_left2_12
# separable_conv_1_bn_normal_right2_12
# separable_conv_1_bn_normal_left5_12
# activation_366
# activation_368
# activation_370
# activation_372
# activation_374
# separable_conv_2_normal_left1_12
# separable_conv_2_normal_right1_12
# separable_conv_2_normal_left2_12
# separable_conv_2_normal_right2_12
# separable_conv_2_normal_left5_12
# separable_conv_2_bn_normal_left1_12
# separable_conv_2_bn_normal_right1_12
# separable_conv_2_bn_normal_left2_12
# separable_conv_2_bn_normal_right2_12
# normal_left3_12
# normal_left4_12
# normal_right4_12
# separable_conv_2_bn_normal_left5_12
# normal_add_1_12
# normal_add_2_12
# normal_add_3_12
# normal_add_4_12
# normal_add_5_12
# normal_concat_12
# activation_375
# global_average_pooling2d_1
# dense_1

# %%
import scipy

parasited_image_idx = np.where(y_pred == 1)[0]

#Save all images classified as parasited to a directory (optional, makes sense for large data sets)
#capture it in memory as an array
predicted_as_para=[]
for i in parasited_image_idx:
    par_img = X_test[i]
    #plt.imsave("results_classified_as_para/para_"+str(i)+".png", par_img)
    predicted_as_para.append(par_img)
    
predicted_as_para = np.array(predicted_as_para)    

# print(img.shape[0],img.shape[1])

from matplotlib.patches import Rectangle #To add a rectangle overlay to the image
from skimage.feature.peak import peak_local_max  #To detect hotspots in 2D images. 
def plot_heatmap(img):
  
    pred = model.predict(np.expand_dims(img, axis=0))
    pred_class = np.argmax(pred)
    print(pred_class)
    #Get weights for all classes from the prediction layer
    last_layer_weights = model.layers[-1].get_weights()[0] #Prediction layer
    print(last_layer_weights.shape)
    #Get weights for the predicted class.
    last_layer_weights_for_pred = last_layer_weights[:, pred_class]
    print(last_layer_weights_for_pred)
    print(last_layer_weights_for_pred.shape)
    #Get output from the last conv. layer
    last_conv_model = Model(model.input, model.get_layer("normal_concat_12").output)
    last_conv_output = last_conv_model.predict(img[np.newaxis,:,:,:])
    last_conv_output = np.squeeze(last_conv_output)
    print(last_conv_output.shape)
    
    #Upsample/resize the last conv. output to same size as original image
    h = int(img.shape[0]/last_conv_output.shape[0])
    w = int(img.shape[1]/last_conv_output.shape[1])
    upsampled_last_conv_output = scipy.ndimage.zoom(last_conv_output, (h, w, 1), order=1)
    
    heat_map = np.dot(upsampled_last_conv_output.reshape((img.shape[0]*img.shape[1], 1056)), 
                 last_layer_weights_for_pred).reshape(img.shape[0],img.shape[1])
    
    #Since we have a lot of dark pixels where the edges may be thought of as 
    #high anomaly, let us drop all heat map values in this region to 0.
    #This is an optional step based on the image. 
    heat_map[img[:,:,0] == 0] = 0  #All dark pixels outside the object set to 0
    
    #Detect peaks (hot spots) in the heat map. We will set it to detect maximum 5 peaks.
    #with rel threshold of 0.5 (compared to the max peak). 
    peak_coords = peak_local_max(heat_map, num_peaks=5, threshold_rel=0.5, min_distance=10) 

    plt.imshow(img.astype('float32').reshape(img.shape[0],img.shape[1],3))
    plt.imshow(heat_map, cmap='jet', alpha=0.30)
    for i in range(0,peak_coords.shape[0]):
        print(i)
        y = peak_coords[i,0]
        x = peak_coords[i,1]
        plt.gca().add_patch(Rectangle((x-25, y-25), 50,50,linewidth=1,edgecolor='r',facecolor='none'))

    

import random 
im = random.randint(0,predicted_as_para.shape[0]-1)
heat_map =plot_heatmap(predicted_as_para[im])

# img = predicted_as_para[im]
# plt.imshow(predicted_as_para[im])
# Out:
# 1
# (1056, 2)
# [ 0.05570143 -0.11947326  0.02536999 ...  0.01811548 -0.01840662
#   0.05775554]
# (1056,)
# (7, 7, 1056)
# 0
# 1

# %%
im
# Out:
# 49
